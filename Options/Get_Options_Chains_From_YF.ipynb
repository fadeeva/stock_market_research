# %%
! pip install -q yfinance

# %%
import pandas as pd
import numpy as np

import yfinance as yf

import matplotlib.pyplot as plt

plt.style.use('ggplot')

# %%
def process_expiration(exp_td_str):
    options = tk.option_chain(exp_td_str)

    calls = options.calls
    puts = options.puts

    calls['optionType'] = 'C'
    puts['optionType'] = 'P'

    exp_data = pd.concat(objs=[calls, puts], ignore_index=True)

    return exp_data

# %%
tk = yf.Ticker('BK')

expirations = tk.options

# %%
expirations
# Out:
# ('2025-03-21',
#  '2025-03-28',
#  '2025-04-04',
#  '2025-04-11',
#  '2025-04-17',
#  '2025-04-25',
#  '2025-05-02',
#  '2025-06-20',
#  '2025-09-19',
#  '2026-01-16',
#  '2026-03-20',
#  '2026-06-18',
#  '2027-01-15')

# %%
data = pd.DataFrame()

for exp_td_str in expirations[:1]:
    exp_data = process_expiration(exp_td_str)
    data = pd.concat(objs=[data, exp_data], ignore_index=True)

# %%
data.sort_values(by='lastTradeDate', ascending=False).head(10)
# Out:
#        contractSymbol             lastTradeDate  strike  lastPrice   bid  \
# 49  BK250321P00075000 2025-03-18 15:25:58+00:00    75.0       0.06  0.05
# 52  BK250321P00077500 2025-03-18 15:06:18+00:00    77.5       0.10  0.05
# 58  BK250321P00082500 2025-03-18 15:06:18+00:00    82.5       1.15  0.95
# 14  BK250321C00080000 2025-03-18 14:53:48+00:00    80.0       2.67  2.55
# 18  BK250321C00083000 2025-03-17 19:59:45+00:00    83.0       0.70  0.55
# 26  BK250321C00090000 2025-03-17 19:55:20+00:00    90.0       0.50  0.00
# 59  BK250321P00083000 2025-03-17 19:47:13+00:00    83.0       1.37  1.20
# 21  BK250321C00086000 2025-03-17 19:34:33+00:00    86.0       0.08  0.00
# 64  BK250321P00087500 2025-03-17 19:28:15+00:00    87.5       4.77  4.90
# 24  BK250321C00088000 2025-03-17 18:52:11+00:00    88.0       0.05  0.00
#
#      ask  change  percentChange  volume  openInterest  impliedVolatility  \
# 49  0.15   -0.39     -86.666670     3.0           316           0.541020
# 52  0.15   -0.10     -50.000000     1.0           836           0.419928
# 58  1.10    0.10       9.523811     1.0          1512           0.269050
# 14  2.70   -0.37     -12.171049    15.0          1017           0.397467
# 18  0.70    0.00       0.000000     4.0           187           0.308601
# 26  0.50    0.45     899.999760     1.0           550           0.652347
# 59  1.35    0.31      29.245290     1.0            19           0.252937
# 21  0.10    0.00       0.000000    13.0            49           0.310554
# 64  5.90    0.00       0.000000     1.0           150           0.656253
# 24  0.50    0.00       0.000000    25.0            62           0.532231
#
#     inTheMoney contractSize currency optionType
# 49       False      REGULAR      USD          P
# 52       False      REGULAR      USD          P
# 58        True      REGULAR      USD          P
# 14        True      REGULAR      USD          C
# 18       False      REGULAR      USD          C
# 26       False      REGULAR      USD          C
# 59        True      REGULAR      USD          P
# 21       False      REGULAR      USD          C
# 64        True      REGULAR      USD          P
# 24       False      REGULAR      USD          C

# %%
data.groupby('optionType').count()
# Out:
#             contractSymbol  lastTradeDate  strike  lastPrice  bid  ask  \
# optionType
# C                       35             35      35         35   35   35
# P                       34             34      34         34   34   34
#
#             change  percentChange  volume  openInterest  impliedVolatility  \
# optionType
# C               35             35      31            35                 35
# P               34             34      31            34                 34
#
#             inTheMoney  contractSize  currency
# optionType
# C                   35            35        35
# P                   34            34        34

# %%
data.groupby('inTheMoney').count()
# Out:
#             contractSymbol  lastTradeDate  strike  lastPrice  bid  ask  \
# inTheMoney
# False                   41             41      41         41   41   41
# True                    28             28      28         28   28   28
#
#             change  percentChange  volume  openInterest  impliedVolatility  \
# inTheMoney
# False           41             41      36            41                 41
# True            28             28      26            28                 28
#
#             contractSize  currency  optionType
# inTheMoney
# False                 41        41          41
# True                  28        28          28
