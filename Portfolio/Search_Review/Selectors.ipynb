# %% [markdown]
# # Selectors

# %%
import pandas as pd
import numpy as np

import datetime as dt
import yfinance as yf

import matplotlib.pyplot as plt
import seaborn as sns

jtplot.style(figsize=(15, 9))

# %%
data = pd.read_csv('../../data/sp500_Company_Overview.csv', index_col=0)
data.head()
# Out:
#            AssetType                  Name  \
# Symbol
# MMM     Common Stock            3M Company
# AOS     Common Stock  Smith AO Corporation
# ABT     Common Stock   Abbott Laboratories
# ABBV    Common Stock            AbbVie Inc
# ACN     Common Stock         Accenture plc
#
#                                               Description        CIK Exchange  \
# Symbol
# MMM     The 3M Company is an American multinational co...    66740.0     NYSE
# AOS     A. O. Smith Corporation is an American manufac...    91142.0     NYSE
# ABT     Abbott Laboratories is an American multination...     1800.0     NYSE
# ABBV    AbbVie is an American publicly traded biopharm...  1551152.0     NYSE
# ACN     Accenture plc is an Irish-domiciled multinatio...  1467373.0     NYSE
#
#        Currency Country            Sector  \
# Symbol
# MMM         USD     USA     LIFE SCIENCES
# AOS         USD     USA     MANUFACTURING
# ABT         USD     USA     LIFE SCIENCES
# ABBV        USD     USA     LIFE SCIENCES
# ACN         USD     USA  TRADE & SERVICES
#
#                                           Industry  \
# Symbol
# MMM     SURGICAL & MEDICAL INSTRUMENTS & APPARATUS
# AOS                           HOUSEHOLD APPLIANCES
# ABT                    PHARMACEUTICAL PREPARATIONS
# ABBV                   PHARMACEUTICAL PREPARATIONS
# ACN                SERVICES-BUSINESS SERVICES, NEC
#
#                                                   Address  ... EVToRevenue  \
# Symbol                                                     ...
# MMM         3M CENTER, BLDG. 220-13E-26A, ST PAUL, MN, US  ...       1.879
# AOS              11270 WEST PARK PLACE, MILWAUKEE, WI, US  ...       3.248
# ABT             100 ABBOTT PARK ROAD, ABBOTT PARK, IL, US  ...       4.928
# ABBV         1 NORTH WAUKEGAN ROAD, NORTH CHICAGO, IL, US  ...        6.15
# ACN     1 GRAND CANAL SQUARE, GRAND CANAL HARBOUR, DUB...  ...       3.041
#
#        EVToEBITDA   Beta 52WeekHigh 52WeekLow 50DayMovingAverage  \
# Symbol
# MMM         -9.08  1.001     105.52     68.63             101.50
# AOS         15.19  1.141      92.44     63.34              83.92
# ABT         18.75  0.718     120.40     88.33             103.84
# ABBV        19.45  0.623     179.55    132.11             166.45
# ACN         18.21  1.227     384.33    277.47             301.44
#
#        200DayMovingAverage SharesOutstanding DividendDate ExDividendDate
# Symbol
# MMM                  98.13      5.533610e+08   2024-06-12     2024-05-23
# AOS                  81.37      1.207840e+08   2024-08-15     2024-07-31
# ABT                 106.60      1.739630e+09   2024-08-15     2024-07-15
# ABBV                162.53      1.765870e+09   2024-08-15     2024-07-15
# ACN                 329.36      6.263840e+08   2024-08-15     2024-07-11
#
# [5 rows x 50 columns]

# %%
data.drop(['AssetType',
           'CIK',
           'Description',
           'Currency',
           'Country',
           'Address',
           'DividendPerShare'
          ], inplace=True, axis=1)

# %%
data.replace('None', np.nan, inplace=True)

data['MarketCapitalization'] = data['MarketCapitalization'].astype(float)
data['Beta'] = data['Beta'].astype(float)
data['PEGRatio'] = data['PEGRatio'].astype(float)
data['PERatio'] = data['PERatio'].astype(float)
data['BookValue'] = data['BookValue'].astype(float)
data['DividendYield'] = data['DividendYield'].astype(float)
data['EPS'] = data['EPS'].astype(float)
data['RevenuePerShareTTM'] = data['RevenuePerShareTTM'].astype(float)
data['ProfitMargin'] = data['ProfitMargin'].astype(float)
data['OperatingMarginTTM'] = data['OperatingMarginTTM'].astype(float)
data['ReturnOnAssetsTTM'] = data['ReturnOnAssetsTTM'].astype(float)
data['EBITDA'] = data['EBITDA'].astype(float)
data['RevenueTTM'] = data['RevenueTTM'].astype(float)
data['GrossProfitTTM'] = data['GrossProfitTTM'].astype(float)
data['DilutedEPSTTM'] = data['DilutedEPSTTM'].astype(float)
data['QuarterlyEarningsGrowthYOY'] = data['QuarterlyEarningsGrowthYOY'].astype(float)
data['QuarterlyRevenueGrowthYOY'] = data['QuarterlyRevenueGrowthYOY'].astype(float)

# %%
multps = {
    'capital'  : ['MarketCapitalization', 'EBITDA', 'BookValue', 'RevenueTTM', 'GrossProfitTTM', ],
    'ratio'    : ['PERatio', 'PEGRatio',],
    'dividend' : ['DividendPerShare', 'DividendYield', 'EPS', 'RevenuePerShareTTM', 'DilutedEPSTTM',],
    'margin'   : ['ProfitMargin', 'OperatingMarginTTM',],
    'returns'  : ['ReturnOnAssetsTTM', 'ReturnOnEquityTTM', 'QuarterlyEarningsGrowthYOY', 'QuarterlyRevenueGrowthYOY'],
}

# %%
data[  (data['PERatio']<16)
     & (data['Beta']>1)
     & (data['PEGRatio']<1)
#      & (data['BookValue']>30)
#      & ((data['DividendYield'] >= 0.02) | (data['DividendYield'] <= 0.06))
     & (data['EPS']>0)
#      & (data['ProfitMargin']>0.07)
#      & (data['OperatingMarginTTM']>0.15)
     & (data['ReturnOnAssetsTTM']>0.05)
     & (data['ReturnOnEquityTTM']>0.14)
#      & (data['QuarterlyRevenueGrowthYOY']>0.1)
    ]
# Out:
#                               Name Exchange                      Sector  \
# Symbol
# APA                APA Corporation   NASDAQ     ENERGY & TRANSPORTATION
# APTV                     Aptiv PLC     NYSE               MANUFACTURING
# BLDR      Builders FirstSource Inc     NYSE            TRADE & SERVICES
# CHTR    Charter Communications Inc   NASDAQ                  TECHNOLOGY
# CMCSA                 Comcast Corp   NASDAQ                  TECHNOLOGY
# COP                 ConocoPhillips     NYSE     ENERGY & TRANSPORTATION
# DVN       Devon Energy Corporation     NYSE     ENERGY & TRANSPORTATION
# DHI                  DR Horton Inc     NYSE  REAL ESTATE & CONSTRUCTION
# JBL              Jabil Circuit Inc     NYSE               MANUFACTURING
# MTCH               Match Group Inc   NASDAQ            TRADE & SERVICES
# NUE                     Nucor Corp     NYSE               MANUFACTURING
# PHM                 PulteGroup Inc     NYSE  REAL ESTATE & CONSTRUCTION
# SLB                Schlumberger NV     NYSE     ENERGY & TRANSPORTATION
# VLO      Valero Energy Corporation     NYSE     ENERGY & TRANSPORTATION
#
#                                                  Industry FiscalYearEnd  \
# Symbol
# APA                         CRUDE PETROLEUM & NATURAL GAS      December
# APTV                    MOTOR VEHICLE PARTS & ACCESSORIES      December
# BLDR     RETAIL-LUMBER & OTHER BUILDING MATERIALS DEALERS      December
# CHTR                CABLE & OTHER PAY TELEVISION SERVICES      December
# CMCSA               CABLE & OTHER PAY TELEVISION SERVICES      December
# COP                                    PETROLEUM REFINING      December
# DVN                         CRUDE PETROLEUM & NATURAL GAS      December
# DHI                                    OPERATIVE BUILDERS     September
# JBL                                PRINTED CIRCUIT BOARDS        August
# MTCH                            RETAIL-RETAIL STORES, NEC      December
# NUE     STEEL WORKS, BLAST FURNACES & ROLLING MILLS (C...      December
# PHM                                    OPERATIVE BUILDERS      December
# SLB                         OIL & GAS FIELD SERVICES, NEC      December
# VLO                                    PETROLEUM REFINING      December
#
#        LatestQuarter  MarketCapitalization        EBITDA  PERatio  PEGRatio  \
# Symbol
# APA       2024-03-31          1.139188e+10  4.942000e+09    3.444     0.170
# APTV      2024-03-31          1.902536e+10  2.871000e+09    6.570     0.675
# BLDR      2024-03-31          1.937411e+10  2.644840e+09   13.640     0.810
# CHTR      2024-03-31          5.294831e+10  2.112600e+10   11.740     0.277
# CMCSA     2024-06-30          1.536995e+11  3.751400e+10   10.560     0.642
# COP       2024-03-31          1.290754e+11  2.428700e+10   12.550     0.721
# DVN       2024-03-31          2.908169e+10  7.140000e+09    8.830     0.395
# DHI       2024-06-30          5.768952e+10  6.516900e+09   11.910     0.599
# JBL       2024-05-31          1.236550e+10  2.262000e+09    9.890     0.910
# MTCH      2024-06-30          9.457010e+09  1.016996e+09   15.940     0.636
# NUE       2024-03-31          3.621605e+10  5.888083e+09   10.880     0.750
# PHM       2024-06-30          2.566034e+10  3.721209e+09    9.440     0.339
# SLB       2024-06-30          6.085434e+10  7.822000e+09   14.010     0.858
# VLO       2024-06-30          4.857283e+10  1.081500e+10    8.560     0.213
#
#         ...  EVToRevenue  EVToEBITDA   Beta  52WeekHigh  52WeekLow  \
# Symbol  ...
# APA     ...        2.143       3.735  3.270       44.81      26.96
# APTV    ...        1.266       10.01  1.794      113.14      65.13
# BLDR    ...        1.565        9.79  2.039      214.70     105.23
# CHTR    ...        2.466        6.49  1.041      458.30     236.08
# CMCSA   ...        2.034        6.36  1.003       46.38      36.13
# COP     ...        2.957        6.48  1.249      134.54     105.08
# DVN     ...        2.589        5.23  2.106       54.67      39.79
# DHI     ...        1.457        8.53  1.711      180.15      99.43
# JBL     ...        0.525        5.74  1.267      156.83      99.99
# MTCH    ...        3.589       12.43  1.490       47.81      27.66
# NUE     ...        1.152        6.21  1.585      202.29     138.78
# PHM     ...        1.532         6.8  1.615      135.62      68.43
# SLB     ...        1.993        8.78  1.566       61.08      42.61
# VLO     ...        0.385        4.79  1.411      182.31     116.43
#
#         50DayMovingAverage  200DayMovingAverage  SharesOutstanding  \
# Symbol
# APA                  29.71                33.15       3.711920e+08
# APTV                 75.92                80.14       2.720620e+08
# BLDR                151.78               162.07       1.220570e+08
# CHTR                292.34               329.16       1.427410e+08
# CMCSA                38.62                41.35       3.863060e+09
# COP                 114.17               117.16       1.164310e+09
# DVN                  47.33                46.76       6.275720e+08
# DHI                 148.54               142.41       3.260400e+08
# JBL                 114.41               125.45       1.134450e+08
# MTCH                 31.82                33.52       2.578950e+08
# NUE                 159.71               171.01       2.397620e+08
# PHM                 116.24               105.82       2.075240e+08
# SLB                  46.15                49.96       1.419840e+09
# VLO                 152.23               146.20       3.203800e+08
#
#         DividendDate  ExDividendDate
# Symbol
# APA       2024-08-22      2024-07-22
# APTV      2020-02-19      2020-02-04
# BLDR             NaN             NaN
# CHTR             NaN             NaN
# CMCSA     2024-07-24      2024-10-02
# COP       2024-06-03      2024-05-10
# DVN       2024-06-28      2024-06-14
# DHI       2024-08-08      2024-08-01
# JBL       2024-09-04      2024-08-15
# MTCH      2018-12-19      2015-11-10
# NUE       2024-08-09      2024-06-28
# PHM       2024-07-02      2024-06-18
# SLB       2024-10-10      2024-09-04
# VLO       2024-09-03      2024-08-01
#
# [14 rows x 43 columns]
