# %% [markdown]
# # Quantitative Momentum

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf
import datetime as dt
import math

from jupyterthemes import jtplot
jtplot.style(theme='onedork', figsize=(15, 9))

# %%
hqm_mom = pd.read_csv('../data/strategy/hqm_momentum.csv', index_col=0)
hqm_mom
# Out:
#     Ticker   Price  Number of Shares to Buy  One-Year Price Return  \
# 0        A  140.19                      NaN               0.116108
# 1      AAL   13.10                      NaN              -0.310526
# 2      AAP  126.87                      NaN              -0.395825
# 3     AAPL  165.23                      NaN               0.006962
# 4     ABBV  161.18                      NaN               0.031554
# ..     ...     ...                      ...                    ...
# 496    YUM  137.10                      NaN               0.131085
# 497    ZBH  133.46                      NaN               0.068028
# 498   ZBRA  300.46                      NaN              -0.236791
# 499   ZION   30.93                      NaN              -0.493531
# 500    ZTS  174.62                      NaN              -0.060161
#
#      One-Year Return Percentile  Six-Month Price Return  \
# 0                           NaN                0.077113
# 1                           NaN               -0.007576
# 2                           NaN               -0.235751
# 3                           NaN                0.165410
# 4                           NaN                0.137103
# ..                          ...                     ...
# 496                         NaN                0.252303
# 497                         NaN                0.212273
# 498                         NaN                0.148372
# 499                         NaN               -0.394247
# 500                         NaN                0.170988
#
#      Six-Month Return Percentile  Three-Month Price Return  \
# 0                            NaN                 -0.096407
# 1                            NaN                 -0.233021
# 2                            NaN                 -0.139079
# 3                            NaN                  0.217318
# 4                            NaN                  0.064338
# ..                           ...                       ...
# 496                          NaN                  0.051945
# 497                          NaN                  0.087023
# 498                          NaN                  0.023435
# 499                          NaN                 -0.387094
# 500                          NaN                  0.096888
#
#      Three-Month Return Percentile  One-Month Price Return  \
# 0                              NaN                0.054350
# 1                              NaN               -0.062947
# 2                              NaN                0.075862
# 3                              NaN                0.066000
# 4                              NaN                0.054745
# ..                             ...                     ...
# 496                            NaN                0.080804
# 497                            NaN                0.075655
# 498                            NaN                0.040698
# 499                            NaN                0.033066
# 500                            NaN                0.061713
#
#      One-Month Return Percentile  HQM Scores
# 0                            NaN         NaN
# 1                            NaN         NaN
# 2                            NaN         NaN
# 3                            NaN         NaN
# 4                            NaN         NaN
# ..                           ...         ...
# 496                          NaN         NaN
# 497                          NaN         NaN
# 498                          NaN         NaN
# 499                          NaN         NaN
# 500                          NaN         NaN
#
# [501 rows x 12 columns]
