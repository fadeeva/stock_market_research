# %% [markdown]
# ## Get Data

# %%
import zipfile, glob
from pathlib import Path
import requests

# %%
url = 'https://www.sec.gov/files/dera/data/financial-statement-notes-data-sets/2025_02_notes.zip'
data_path = Path('data')
filename = data_path / url.split('/')[-1]

if not data_path.exists():
    print('Creating directory')
    data_path.mkdir()
if not filename.exists():
    print('Downloading...', url)
    headers = {
            'Host': 'www.sec.gov', 'Connection': 'close',
            'Accept': 'application/json, text/javascript, */*; q=0.01', 'X-Requested-With': 'XMLHttpRequest',
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.163 Safari/537.36',
         }
    r = requests.get(url, headers=headers, allow_redirects=True)
    open(filename, 'wb').write(r.content)

if filename.exists():
    extract_dir = 'data'
    print('Extracting files...')
    with zipfile.ZipFile(filename) as zf:
        zf.extractall(extract_dir)
    for file in glob.glob(extract_dir + '/**', recursive=True):
        print(file)

print('...DONE')
# Out:
# Creating directory
# Downloading... https://www.sec.gov/files/dera/data/financial-statement-notes-data-sets/2025_02_notes.zip
# Extracting files...
# data/
# data/readme.htm
# data/2025_02_notes.zip
# data/tag.tsv
# data/pre.tsv
# data/num.tsv
# data/dim.tsv
# data/sub.tsv
# data/txt.tsv
# data/notes-metadata.json
# data/ren.tsv
# data/cal.tsv
# ...DONE

# %% [markdown]
# ## Observe Data

# %%
import pandas as pd

# %%
cal_df = pd.read_csv('data/cal.tsv', sep='\t')
cal_df.head()
# Out:
#                    adsh  grp  arc  negative                       ptag  \
# 0  0001504461-25-000004   12    5         1  AccruedLiabilitiesCurrent
# 1  0000769520-25-000009    3    1         1  AccruedLiabilitiesCurrent
# 2  0001504461-25-000004   12    2         1  AccruedLiabilitiesCurrent
# 3  0001558370-25-001736   19   26         1                     Assets
# 4  0001025835-25-000039    7    2         1                     Assets
#
#        pversion                                               ctag  \
# 0  us-gaap/2023                                TaxesPayableCurrent
# 1  us-gaap/2023               ContractWithCustomerLiabilityCurrent
# 2  us-gaap/2023                                DistributionPayable
# 3  us-gaap/2023  PropertyPlantAndEquipmentAndFinanceLeaseRightO...
# 4  us-gaap/2023                       PropertyPlantAndEquipmentNet
#
#        cversion
# 0  us-gaap/2023
# 1  us-gaap/2023
# 2  us-gaap/2023
# 3  us-gaap/2023
# 4  us-gaap/2023

# %%
cal_df.shape
# Out:
# (477029, 8)

# %%
cal_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 477029 entries, 0 to 477028
# Data columns (total 8 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   adsh      477029 non-null  object
#  1   grp       477029 non-null  int64
#  2   arc       477029 non-null  int64
#  3   negative  477029 non-null  int64
#  4   ptag      477029 non-null  object
#  5   pversion  477029 non-null  object
#  6   ctag      477029 non-null  object
#  7   cversion  477029 non-null  object
# dtypes: int64(3), object(5)
# memory usage: 29.1+ MB

# %%
cal_df['ptag'].nunique(), cal_df['ctag'].nunique()
# Out:
# (9224, 57900)

# %%
dim_df = pd.read_csv('data/dim.tsv', sep='\t')
dim_df.head()
# Out:
#                               dimhash  \
# 0  0x0942d94b9d9266bf273a2c5123d68019
# 1  0xf48392632836a4db259a7d67c3a4f808
# 2  0x09d3f28b05928a485eb5ca0cf40bc7d0
# 3  0xb0703db550a95f6c213269cbf1bed75e
# 4  0x89eebd7929107c732859066c1c17c60e
#
#                                             segments  segt
# 0  BalanceSheetLocation=OtherAccruedLiabilities;D...     0
# 1  RangesOfExercisePricesForOutstandingShareOptio...     0
# 2  BusinessSegments=LargeAccountSegment;ProductOr...     0
# 3  MajorPropertyClassUsefulLife=Furnitureequipmen...     0
# 4     DebtInstrument=SeniorUnsecuredNotesDueMay2023;     0

# %%
dim_df.shape
# Out:
# (417834, 3)

# %%
dim_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 417834 entries, 0 to 417833
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   dimhash   417834 non-null  object
#  1   segments  417833 non-null  object
#  2   segt      417834 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 9.6+ MB

# %%
dim_df['segments'].nunique()
# Out:
# 417830

# %%
pre_df = pd.read_csv('data/pre.tsv', sep='\t')
pre_df.head()
# Out:
#                    adsh  report  line stmt  inpth            tag   version  \
# 0  0001104659-25-008644       1     2  NaN      0  AmendmentFlag  dei/2023
# 1  0000826154-25-000036       1    23  NaN      0  AmendmentFlag  dei/2023
# 2  0001670541-25-000021       1    25  NaN      0  AmendmentFlag  dei/2023
# 3  0001437749-25-002597       1    22  NaN      0  AmendmentFlag  dei/2023
# 4  0001589526-25-000017       1    23  NaN      0  AmendmentFlag  dei/2023
#
#         prole          plabel  negating
# 0       label  Amendment Flag         0
# 1  terseLabel  Amendment Flag         0
# 2  terseLabel  Amendment Flag         0
# 3       label  Amendment Flag         0
# 4  terseLabel  Amendment Flag         0

# %%
pre_df.shape
# Out:
# (3218749, 10)

# %%
pre_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3218749 entries, 0 to 3218748
# Data columns (total 10 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   adsh      object
#  1   report    int64
#  2   line      int64
#  3   stmt      object
#  4   inpth     int64
#  5   tag       object
#  6   version   object
#  7   prole     object
#  8   plabel    object
#  9   negating  int64
# dtypes: int64(4), object(6)
# memory usage: 245.6+ MB

# %%
pre_df.groupby('prole').count()
# Out:
#                             adsh   report     line    stmt    inpth      tag  \
# prole
# axisDefault                   27       27       27       1       27       27
# commentaryGuidance             3        3        3       1        3        3
# definitionGuidance           363      363      363      77      363      363
# disclosureGuidance            52       52       52       3       52       52
# documentation                 47       47       47       3       47       47
# exampleGuidance                1        1        1       0        1        1
# label                     501886   501886   501886   81649   501886   501886
# measurementGuidance            6        6        6       1        6        6
# negatedLabel               76491    76491    76491   36452    76491    76491
# negatedNetLabel              460      460      460     149      460      460
# negatedPeriodEndLabel        828      828      828     127      828      828
# negatedPeriodStartLabel      826      826      826     119      826      826
# negatedTerseLabel          62027    62027    62027   22653    62027    62027
# negatedTotalLabel           5351     5351     5351     601     5351     5351
# negativeLabel                  7        7        7       2        7        7
# negativeTerseLabel             1        1        1       1        1        1
# netLabel                    6293     6293     6293     972     6293     6293
# periodEndLabel             32108    32108    32108    8823    32108    32108
# periodStartLabel           31246    31246    31246    8744    31246    31246
# positiveLabel                244      244      244      64      244      244
# positiveTerseLabel            75       75       75      14       75       75
# positiveVerboseLabel          19       19       19       1       19       19
# presentationGuidance         139      139      139      30      139      139
# terseLabel               2204175  2204175  2204175  334807  2204175  2204174
# totalLabel                119961   119961   119961   53707   119961   119961
# verboseLabel              176104   176104   176104   35969   176104   176104
# zeroLabel                      4        4        4       1        4        4
# zeroTerseLabel                 4        4        4       1        4        4
# zeroVerboseLabel               1        1        1       0        1        1
#
#                          version   plabel  negating
# prole
# axisDefault                   27       27        27
# commentaryGuidance             3        3         3
# definitionGuidance           363      363       363
# disclosureGuidance            52       52        52
# documentation                 47       47        47
# exampleGuidance                1        1         1
# label                     501886   501881    501886
# measurementGuidance            6        6         6
# negatedLabel               76491    76491     76491
# negatedNetLabel              460      460       460
# negatedPeriodEndLabel        828      828       828
# negatedPeriodStartLabel      826      826       826
# negatedTerseLabel          62027    62027     62027
# negatedTotalLabel           5351     5351      5351
# negativeLabel                  7        7         7
# negativeTerseLabel             1        1         1
# netLabel                    6293     6293      6293
# periodEndLabel             32108    32108     32108
# periodStartLabel           31246    31246     31246
# positiveLabel                244      244       244
# positiveTerseLabel            75       75        75
# positiveVerboseLabel          19       19        19
# presentationGuidance         139      139       139
# terseLabel               2204175  2204168   2204175
# totalLabel                119961   119960    119961
# verboseLabel              176104   176076    176104
# zeroLabel                      4        4         4
# zeroTerseLabel                 4        4         4
# zeroVerboseLabel               1        1         1

# %%
pre_df['plabel'].nunique()
# Out:
# 707319

# %%
ren_df = pd.read_csv('data/ren.tsv', sep='\t')
ren_df.head()
# Out:
#                    adsh  report rfile menucat shortname  \
# 0  0001628280-25-003396       1     H       C     Cover
# 1  0001493152-25-004617       1     H       C     Cover
# 2  0001493152-25-004615       1     H       C     Cover
# 3  0001493152-25-004614       1     H       C     Cover
# 4  0001493152-25-004609       1     H       C     Cover
#
#                       longname                                   roleuri  \
# 0   0000001 - Document - Cover      http://daveandbusters.com/role/Cover
# 1  00000001 - Document - Cover     http://fr8technologies.com/role/Cover
# 2  00000001 - Document - Cover         http://microvision.com/role/Cover
# 3  00000001 - Document - Cover  http://safetyshotofficial.com/role/Cover
# 4  00000001 - Document - Cover           http://aimimmuno.com/role/Cover
#
#   parentroleuri  parentreport  ultparentrpt
# 0           NaN           NaN           NaN
# 1           NaN           NaN           NaN
# 2           NaN           NaN           NaN
# 3           NaN           NaN           NaN
# 4           NaN           NaN           NaN

# %%
ren_df.shape
# Out:
# (269397, 10)

# %%
ren_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269397 entries, 0 to 269396
# Data columns (total 10 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   adsh           269397 non-null  object
#  1   report         269397 non-null  int64
#  2   rfile          269397 non-null  object
#  3   menucat        269397 non-null  object
#  4   shortname      269387 non-null  object
#  5   longname       269397 non-null  object
#  6   roleuri        269397 non-null  object
#  7   parentroleuri  73787 non-null   object
#  8   parentreport   73787 non-null   float64
#  9   ultparentrpt   133446 non-null  float64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 20.6+ MB

# %%
sub_df = pd.read_csv('data/sub.tsv', sep='\t')
sub_df.head()
# Out:
#                    adsh    cik                    name     sic countryba  \
# 0  0000012927-25-000015  12927               BOEING CO  3721.0        US
# 1  0000017313-25-000009  17313  CAPITAL SOUTHWEST CORP     NaN        US
# 2  0000021076-25-000010  21076          CLOROX CO /DE/  2842.0        US
# 3  0000021076-25-000013  21076          CLOROX CO /DE/  2842.0        US
# 4  0000035527-25-000012  35527     FIFTH THIRD BANCORP  6022.0        US
#
#   stprba      cityba       zipba                   bas1                bas2  \
# 0     VA   ARLINGTON       22202  929 LONG BRIDGE DRIVE                 NaN
# 1     TX      DALLAS       75225       8333 DOUGLAS AVE          SUITE 1100
# 2     CA     OAKLAND  94612-1888     THE CLOROX COMPANY       1221 BROADWAY
# 3     CA     OAKLAND  94612-1888     THE CLOROX COMPANY       1221 BROADWAY
# 4     OH  CINCINNATI       45263     38 FOUNTAIN SQ PLZ  FIFTH THIRD CENTER
#
#    ...               accepted prevrpt detail               instance nciks  \
# 0  ...  2025-02-03 14:38:00.0       0      1    ba-20241231_htm.xml     1
# 1  ...  2025-02-03 16:06:00.0       0      0  cswc-20250203_htm.xml     1
# 2  ...  2025-02-03 16:12:00.0       0      0   clx-20250203_htm.xml     1
# 3  ...  2025-02-03 16:45:00.0       0      1   clx-20241231_htm.xml     1
# 4  ...  2025-02-03 08:35:00.0       0      0  fitb-20250203_htm.xml     1
#
#   aciks   pubfloatusd   floatdate floataxis  floatmems
# 0   NaN  1.120000e+11  20240630.0       NaN        1.0
# 1   NaN           NaN         NaN       NaN        NaN
# 2   NaN           NaN         NaN       NaN        NaN
# 3   NaN           NaN         NaN       NaN        NaN
# 4   NaN           NaN         NaN       NaN        NaN
#
# [5 rows x 40 columns]

# %%
sub_df.shape
# Out:
# (8863, 40)

# %%
sub_df.columns
# Out:
# Index(['adsh', 'cik', 'name', 'sic', 'countryba', 'stprba', 'cityba', 'zipba',
#        'bas1', 'bas2', 'baph', 'countryma', 'stprma', 'cityma', 'zipma',
#        'mas1', 'mas2', 'countryinc', 'stprinc', 'ein', 'former', 'changed',
#        'afs', 'wksi', 'fye', 'form', 'period', 'fy', 'fp', 'filed', 'accepted',
#        'prevrpt', 'detail', 'instance', 'nciks', 'aciks', 'pubfloatusd',
#        'floatdate', 'floataxis', 'floatmems'],
#       dtype='object')

# %%
tag_df = pd.read_csv('data/tag.tsv', sep='\t')
tag_df.head()
# Out:
#                                        tag               version  custom  \
# 0  A.5000EuroDenominatedNotesDue2033Member  0000059478-25-000067       1
# 1       A.C.SolucoesParaPiscinasLda.Member  0000945841-25-000032       1
# 2               A.NattermannCie.GmbHMember  0001121404-25-000010       1
# 3                          A.PacificMember  0000021344-25-000011       1
# 4        A0.0007.500NotesDue20252028Member  0001628280-25-009007       1
#
#    abstract datatype iord crdr  \
# 0         1   member  NaN  NaN
# 1         1   member  NaN  NaN
# 2         1   member  NaN  NaN
# 3         1   member  NaN  NaN
# 4         1   member  NaN  NaN
#
#                                             tlabel  \
# 0  .5000% Euro Denominated Notes Due 2033 [Member]
# 1       A.C. Solucoes para Piscinas, Lda. [Member]
# 2               A. Nattermann & Cie. GmbH [Member]
# 3                              A. Pacific [Member]
# 4       0.000% 7.500% Notes Due 2025/2028 [Member]
#
#                                                  doc
# 0             .5000% Euro Denominated Notes Due 2033
# 1                  A.C. Solucoes para Piscinas, Lda.
# 2                 A. Nattermann & Cie. GmbH [Member]
# 3  A component of an entity for which there is an...
# 4                  0.000% 7.500% Notes Due 2025/2028

# %%
tag_df.shape
# Out:
# (514013, 9)

# %%
txt_df = pd.read_csv('data/txt.tsv', sep='\t')
txt_df.head()
# Out:
#                    adsh                                               tag  \
# 0  0000004127-25-000010                             EntityCentralIndexKey
# 1  0000005513-25-000002                                  LocalPhoneNumber
# 2  0000005513-25-000015         StockholdersEquityNoteDisclosureTextBlock
# 3  0000006201-25-000010  FairValueAssetsMeasuredOnRecurringBasisTextBlock
# 4  0000016868-25-000011                        DebtInstrumentMaturityDate
#
#         version     ddate  qtrs  iprx   lang   dcml      durp  datp  \
# 0      dei/2024  20241231     1     0  en-US  32767  0.013699   4.0
# 1      dei/2024  20250131     0     0  en-US  32767  0.000000  -4.0
# 2  us-gaap/2024  20241231     4     0  en-US  32767  0.000000   0.0
# 3  us-gaap/2024  20241231     4     0  en-US  32767  0.000000   0.0
# 4  us-gaap/2024  20241231     4     0  en-US  32767  0.000000   0.0
#
#                                  dimh  dimn coreg  escaped  srclen  txtlen  \
# 0                          0x00000000     0   NaN        0      10      10
# 1                          0x00000000     0   NaN        0       8       8
# 2                          0x00000000     0   NaN        1   50371    4969
# 3                          0x00000000     0   NaN        1   51969    1940
# 4  0x3eb07b98254e11d113e6e3d4fd075180     1   NaN        0      10      10
#
#   footnote  footlen context                                              value
# 0      NaN        0     c-1                                         0000004127
# 1      NaN        0     c-1                                           294-1011
# 2      NaN        0     c-1  Common Stock As part of our capital deployment...
# 3      NaN        0     c-1  Assets measured at fair value on a recurring b...
# 4      NaN        0   c-160                                         2033-11-01

# %%
txt_df.shape
# Out:
# (687066, 20)

# %%
txt_df['tag'].nunique()
# Out:
# 34946
